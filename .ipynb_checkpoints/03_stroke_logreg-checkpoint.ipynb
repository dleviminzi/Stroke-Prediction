# %%
import itertools
import warnings 

import numpy as np
import pandas as pd
import statsmodels.api as sm
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_predict
from sklearn.feature_selection import RFECV
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

from helpers import model_report_from

# %%
# sometimes optimization fails to converge during grid search and i dont care
warnings.filterwarnings('ignore')

# %%
ft_train = np.load("./processed_data/features_train.npy")
ft_test = np.load("./processed_data/features_test.npy")
lbl_train = np.load("./processed_data/labels_train.npy")
lbl_test = np.load("./processed_data/labels_test.npy")

# %%
features = np.load("./processed_data/features.npy")
labels = np.load("./processed_data/labels.npy")

# %%
feature_names = np.load("./processed_data/feature_names.npy")

# %% [markdown]
# # Linear Regression

# %%
# goal here is to get p-values as an early estimate of feature importance 
sm.add_constant(ft_train)
est = sm.OLS(lbl_train, ft_train)

# fit with statsmodels package instead of sklearn 
result = est.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.079
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     19.26
# Date:                Mon, 31 May 2021   Prob (F-statistic):           6.32e-60
# Time:                        15:42:12   Log-Likelihood:                 646.52
# No. Observations:                4088   AIC:                            -1255.
# Df Residuals:                    4069   BIC:                            -1135.
# Df Model:                          18
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          1.157e+11      2e+11      0.578      0.563   -2.77e+11    5.08e+11
# x2          1.157e+11      2e+11      0.578      0.563   -2.77e+11    5.08e+11
# x3          1.157e+11      2e+11      0.578      0.563   -2.77e+11    5.08e+11
# x4          1.157e+11      2e+11      0.578      0.563   -2.77e+11    5.08e+11
# x5          2.519e+12   5.05e+11      4.987      0.000    1.53e+12    3.51e+12
# x6          2.519e+12   5.05e+11      4.987      0.000    1.53e+12    3.51e+12
# x7          2.519e+12   5.05e+11      4.987      0.000    1.53e+12    3.51e+12
# x8          2.519e+12   5.05e+11      4.987      0.000    1.53e+12    3.51e+12
# x9          2.519e+12   5.05e+11      4.987      0.000    1.53e+12    3.51e+12
# x10         1.272e+11    6.4e+11      0.199      0.843   -1.13e+12    1.38e+12
# x11         1.272e+11    6.4e+11      0.199      0.843   -1.13e+12    1.38e+12
# x12         2.059e+11   4.35e+11      0.473      0.636   -6.47e+11    1.06e+12
# x13         2.059e+11   4.35e+11      0.473      0.636   -6.47e+11    1.06e+12
# x14         2.059e+11   4.35e+11      0.473      0.636   -6.47e+11    1.06e+12
# x15        -2.968e+12   9.24e+11     -3.211      0.001   -4.78e+12   -1.16e+12
# x16        -2.968e+12   9.24e+11     -3.211      0.001   -4.78e+12   -1.16e+12
# x17            0.0715      0.005     13.052      0.000       0.061       0.082
# x18            0.0139      0.003      4.029      0.000       0.007       0.021
# x19            0.0108      0.003      3.168      0.002       0.004       0.018
# x20            0.0096      0.003      2.803      0.005       0.003       0.016
# x21           -0.0039      0.004     -0.886      0.376      -0.012       0.005
# x22           -0.0027      0.004     -0.695      0.487      -0.010       0.005
# ==============================================================================
# Omnibus:                     3024.440   Durbin-Watson:                   2.009
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37159.161
# Skew:                           3.611   Prob(JB):                         0.00
# Kurtosis:                      15.884   Cond. No.                     7.53e+14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.71e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
# removes all features that are not about smoking pretty much
# ft_train = ft_train[:,14:]
# ft_test = ft_test[:,14:]
# features = features[:,14:]

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# ## Hyperparameter tuning

# %%
param = {
    'C' : [0.001,0.003,0.005,0.01,0.03,0.05,0.1,0.3,0.5,1,2,3,3,4,5],
}
clf = GridSearchCV(LogisticRegression(class_weight='balanced'), param, scoring='recall', refit=True, cv=10)

# %%
clf.fit(ft_train, lbl_train)
clf.best_params_
# Out:
# {'C': 0.005}

# %% [markdown]
# ## Training the model

# %%
lr = LogisticRegression(class_weight='balanced', C=clf.best_params_['C'])

# %%
lr.fit(ft_train, lbl_train)
# Out:
# LogisticRegression(C=0.005, class_weight='balanced')

# %% [markdown]
# ## Results from the model

# %%
model_report_from(lr, ft_test, lbl_test, [])
# Out:
# accuracy = 0.7289628180039138
# precision = 0.13968253968253969
# recall = 0.88
# f1 = 0.2410958904109589
# ROC AUC score = 0.80059670781893

# %% [markdown]
# ## Feature importance

# %%
# using recursive feature elimination to determine importance of features
selector = RFECV(lr, step=1, cv=5).fit(ft_train, lbl_train)
selector.ranking_
# Out:
# array([4, 1, 1, 1, 3, 5, 1, 7, 1, 1, 1, 8, 6, 9, 1, 1, 1, 1, 1, 1, 2, 1])

# %%
# this one seems to make the most sense
[feature for i, feature in enumerate(feature_names) if selector.ranking_[i] == 1]
# Out:
# ['formerly smoked',
#  'never smoked',
#  'smokes',
#  'Private',
#  'children',
#  'Rural',
#  'Urban',
#  'No',
#  'Yes',
#  'age',
#  'hypertension',
#  'heart_disease',
#  'avg_glucose_level',
#  'age_weighted_bmi_deviation']

# %%
# trying to train model on reduced information
ft_train_fi = [[ft for i, ft in enumerate(row) if selector.ranking_[i] == 1] for row in ft_train]
ft_test_fi = [[ft for i, ft in enumerate(row) if selector.ranking_[i] == 1] for row in ft_test]

# %%
# makes model a bit worse
lr_fi = LogisticRegression(class_weight='balanced', C=clf.best_params_['C'])
lr_fi.fit(ft_train_fi, lbl_train)
model_report_from(lr_fi, ft_test_fi, lbl_test, [])
# Out:
# accuracy = 0.7279843444227005
# precision = 0.13924050632911392
# recall = 0.88
# f1 = 0.24043715846994534
# ROC AUC score = 0.8000823045267489

# %% [markdown]
# ## Taking a look at those that went wrong

# %%
df = pd.read_csv('./raw_data/dataset-stroke.csv').drop(columns=['id'])

# %%
df['pred_stroke'] = lr.predict(features)
df['prob_pos'] = lr.predict_proba(features)[:,1]

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke  \
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1
#
#    pred_stroke  prob_pos
# 0            1  0.809483
# 1            1  0.565891
# 2            1  0.800375
# 3            0  0.461261
# 4            1  0.822961

# %%
# False negatives (most dire)
df[df.pred_stroke == 0][df.stroke == 1].hist(figsize=(20, 10))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'hypertension'}>,
#         <AxesSubplot:title={'center':'heart_disease'}>],
#        [<AxesSubplot:title={'center':'avg_glucose_level'}>,
#         <AxesSubplot:title={'center':'bmi'}>,
#         <AxesSubplot:title={'center':'stroke'}>],
#        [<AxesSubplot:title={'center':'pred_stroke'}>,
#         <AxesSubplot:title={'center':'prob_pos'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df[df.stroke==1][df.stroke == df.pred_stroke].hist(figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'hypertension'}>,
#         <AxesSubplot:title={'center':'heart_disease'}>],
#        [<AxesSubplot:title={'center':'avg_glucose_level'}>,
#         <AxesSubplot:title={'center':'bmi'}>,
#         <AxesSubplot:title={'center':'stroke'}>],
#        [<AxesSubplot:title={'center':'pred_stroke'}>,
#         <AxesSubplot:title={'center':'prob_pos'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df[df.stroke == 1].hist(figsize=(20,10))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'hypertension'}>,
#         <AxesSubplot:title={'center':'heart_disease'}>],
#        [<AxesSubplot:title={'center':'avg_glucose_level'}>,
#         <AxesSubplot:title={'center':'bmi'}>,
#         <AxesSubplot:title={'center':'stroke'}>],
#        [<AxesSubplot:title={'center':'pred_stroke'}>,
#         <AxesSubplot:title={'center':'prob_pos'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ## Testing result of lowering probability threshold

# %%
df['low_thresh_stroke'] = df.prob_pos.apply(lambda x: 1 if x > 0.35 else 0)

# %%
model_report_from(lr, features, labels, y_test_pred=df.low_thresh_stroke.to_numpy())
# Out:
# accuracy = 0.5673189823874756
# precision = 0.09596375617792421
# recall = 0.9357429718875502
# f1 = 0.17407545760179305
# ROC AUC score = 0.742094896764594

# %%
# vanilla (all data)
model_report_from(lr, features, labels, [])
# Out:
# accuracy = 0.7318982387475539
# precision = 0.13485342019543975
# recall = 0.8313253012048193
# f1 = 0.23206278026905833
# ROC AUC score = 0.7790652426616568
